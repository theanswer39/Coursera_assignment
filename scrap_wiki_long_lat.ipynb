# %% [markdown]
# # Ectracting the List of postal codes of Canada: M using web scrapping
# This notebook contains the code to scrap the list of postal codes of canada and convert it into a dataframe.

# %% [markdown]
# #### Importing the required libraries

# %%
import pandas as pd
import requests

# %% [markdown]
# #### Setting the url to the given wikipedia page which contains the list. then making the rwquest to get the data

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %% [markdown]
# #### Reading the dataframe from the data then refining the dataframe to get the required table.

# %%
df = pd.read_html(url)[0]

# %%
df
# Out:
#                                                     0  \
# 0                                     M1ANot assigned
# 1                     M1BScarborough(Malvern / Rouge)
# 2   M1CScarborough(Rouge Hill / Port Union / Highl...
# 3   M1EScarborough(Guildwood / Morningside / West ...
# 4                              M1GScarborough(Woburn)
# 5                           M1HScarborough(Cedarbrae)
# 6                 M1JScarborough(Scarborough Village)
# 7   M1KScarborough(Kennedy Park / Ionview / East B...
# 8   M1LScarborough(Golden Mile / Clairlea / Oakridge)
# 9   M1MScarborough(Cliffside / Cliffcrest / Scarbo...
# 10       M1NScarborough(Birch Cliff / Cliffside West)
# 11  M1PScarborough(Dorset Park / Wexford Heights /...
# 12                 M1RScarborough(Wexford / Maryvale)
# 13                          M1SScarborough(Agincourt)
# 14  M1TScarborough(Clarks Corners / Tam O'Shanter ...
# 15  M1VScarborough(Milliken / Agincourt North / St...
# ...

# %% [markdown]
# #### Shape of the dataframe and the dataframe is printed below.

# %%
table = []
for column in df.columns:
    for item in df[column]:
        if item[3:] != 'Not assigned':
            table.append([item[:3], item[3:].split('(')[0], item[3:].split('(')[1][:-1].replace(' / ', ', ')])
            
data_frame = pd.DataFrame(table, columns = ['Postal Code', 'Borough', 'Neighborhood']).dropna().sort_values(by = 'Postal Code').reset_index().drop(columns = ['index'])
data_frame
# Out:
#     Postal Code             Borough  \
# 0           M1B         Scarborough
# 1           M1C         Scarborough
# 2           M1E         Scarborough
# 3           M1G         Scarborough
# 4           M1H         Scarborough
# ..          ...                 ...
# 98          M9N                York
# 99          M9P           Etobicoke
# 100         M9R           Etobicoke
# 101         M9V           Etobicoke
# 102         M9W  EtobicokeNorthwest
#
#                                           Neighborhood
# 0                                       Malvern, Rouge
# 1               Rouge Hill, Port Union, Highland Creek
# 2                    Guildwood, Morningside, West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# ..                                                 ...
# 98                                              Weston
# 99                                           Westmount
# ...

# %%
data_frame.shape
# Out:
# (103, 3)

# %%
# import geocoder # import geocoder

# %%
# postal_codes = list(data_frame['Postal Code'])

# %%
postal_ll = pd.read_csv('Geospatial_Coordinates.csv')

# %%
postal_ll.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
data_frame['latitude'] = postal_ll['Latitude']
data_frame['longitude'] = postal_ll['Longitude']

# %%
data_frame
# Out:
#     Postal Code             Borough  \
# 0           M1B         Scarborough
# 1           M1C         Scarborough
# 2           M1E         Scarborough
# 3           M1G         Scarborough
# 4           M1H         Scarborough
# ..          ...                 ...
# 98          M9N                York
# 99          M9P           Etobicoke
# 100         M9R           Etobicoke
# 101         M9V           Etobicoke
# 102         M9W  EtobicokeNorthwest
#
#                                           Neighborhood   latitude  longitude
# 0                                       Malvern, Rouge  43.806686 -79.194353
# 1               Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 2                    Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# ...
